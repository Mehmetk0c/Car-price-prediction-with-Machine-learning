# %%
from tkinter import *
from tkinter.ttk import *
import joblib
from datetime import datetime
from tkinter import messagebox
from PIL import Image, ImageTk

# %%
modeldict={
"audia3sedan1.6tdiattractiona3"	:"0",
"audia4sedan2.0tdia4"	:"1",
"audia6sedan2.0tdia6"	:"2",
"bmw316icomfort3serisi"	:"3",
"bmw316istandart3serisi"	:"4",
"bmw318istandart3serisi"	:",5",
"bmw320dmsport3serisi"	:"6",
"bmw320dpremium3serisi"	:"7",
"bmw320dstandart3serisi"	:"8",
"bmw320i3serisi"	:"10",
"bmw320iedsportline3serisi"	:"9",
"bmw520dpremium5serisi"	:"11",
"bmw520ipremium5serisi"	:"12",
"bmw520istandart5serisi"	:"13",
"chevrolet1.6lscruze"	:"15",
"chevrolet1.6lspluscruze"	:"14",
"citroen1.6hdiattractionc-elysee"	:"16",
"citroen1.6hdiconfortc-elysee"	:"17",
"citroen1.6hdiexclusivec-elysee"	:"18",
"citroen1.6hdilivec-elysee"	:"19",
"citroen1.6hdisxc4"	:"21",
"citroen1.6hdisxc5"	:"22",
"citroen1.6hdisxpkc5"	:"20",
"dacia0.9tcestepwayeasy-rsandero"	:"23",
"dacia1.5dcilaureatelodgy"	:"24",
"dacia1.5dcimcvambiancelogan"	:"25",
"dacia1.5dcistepwaysandero"	:"26",
"fiat1.2elalbea"	:"27",
"fiat1.2elpalio"	:"28",
"fiat1.3multijetactivealbea"	:"30",
"fiat1.3multijetactivelinea"	:"31",
"fiat1.3multijetactivepluslinea"	:"29",
"fiat1.3multijeteasyegea"	:"32",
"fiat1.3multijeteasylinea"	:"33",
"fiat1.3multijetpoplinea"	:"34",
"fiat1.3multijeturbanegea"	:"36",
"fiat1.3multijeturbanlinea"	:"37",
"fiat1.3multijeturbanplusegea"	:"35",
"fiat1.4elpalio"	:"38",
"fiat1.4elsiena"	:"39",
"fiat1.4fireeasyegea"	:"41",
"fiat1.4fireeasyplusegea"	:"40",
"fiat1.4firepoplinea"	:"42",
"fiat1.4fireurbanegea"	:"44",
"fiat1.4fireurbanplusegea"	:"43",
"fiat1.6hlpalio"	:"45",
"fiat1.6libertymarea"	:"46",
"fiat1.6multijetcomfortegea"	:"47",
"fiat1.6multijetloungeegea"	:"48",
"fiat1.6multijeturbanegea"	:"49",
"fiat1.6slxtipo"	:"50",
"fiat1.6sxatempra"	:"51",
"fiat1.6sxtempra"	:"52",
"fiat1.6sxtipo"	:"53",
"fiat70suno"	:"54",
"fiat70sxuno"	:"55",
"fiatgrande1.3multijetactivepunto"	:"56",
"fiatgrande1.4fireactivepunto"	:"57",
"fiatsole1.3multijetdynamicalbea"	:"58",
"ford1.25trendfiesta"	:"60",
"ford1.25trendxfiesta"	:"59",
"ford1.4comfortfiesta"	:"61",
"ford1.4tdcicomfortfiesta"	:"62",
"ford1.4tdcititaniumfiesta"	:"64",
"ford1.4tdcititaniumxfiesta"	:"63",
"ford1.4tdcitrendfiesta"	:"65",
"ford1.4titaniumfiesta"	:"67",
"ford1.4titaniumxfiesta"	:"66",
"volkswagen1.6tdibluemotionhighlinegolf"	:"351",
"volkswagen1.6tdibluemotionhighlinepassat"	:"352",
"volkswagen1.6tdibluemotionimpressionpassat"	:"353",
"volkswagen1.6tdibluemotionmidlineplusgolf"	:"354",
"volkswagen1.6tdibluemotiontrendlinepassat"	:"355",
"volkswagen1.6tdicomfortlinegolf"	:"356",
"volkswagen1.6tdicomfortlinejetta"	:"357",
"volkswagen1.6tdicomfortlinepolo"	:"358",
"volkswagen1.6tdihighlinejetta"	:"359",
"volkswagen1.6tditrendlinegolf"	:"360",
"volkswagen1.6tditrendlinejetta"	:"361",
"volkswagen1.6trendlinegolf"	:"362",
"volkswagen1.6trendlinepassat"	:"363",
"volkswagen1.8tcomfortlinepassat"	:"365",
"volkswagen1.9tdicomfortlinepassat"	:"366",
"volkswagen2.0tdibluemotioncomfortlinepassat"	:"367",
"volkswagen2.0tdibluemotionhighlinepassat"	:"368",
"volkswagen2.0tdicomfortlinepassat"	:"369",
"volvo1.6dadvances60"	:"370"   
}

# %%
root = Tk(className="Araç Tahmin")

root.geometry("1280x729")
root.resizable(width=False, height=False)
bg = PhotoImage(gamma=1,file = "back.png")

# Show image using label
label1 = Label( root, image = bg)
label1.place(x = 0, y = 0)


label2 = Label( root, text = "MARKA:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label2.grid(column=20, row=0,padx=(500, 210),pady=(20, 20))

variable_1 =StringVar()
variable_1.set("Marka")
values_1 = {
    "Alfa Romeo":"0",
    "Audi":"1",
    "BMW":       "2",
    "Chevrolet": "3",
    "Citroen":   "4",
    "Dacia":     "5",
    "Daewoo":    "6",
    "Fiat":      "7",
    "Ford":      "8",
    "Honda":     "9",
    "Hyundai":  "10",
    "Infiniti": "11",
    "Kia":      "12",
    "Lada":     "13",
    "MINI":     "14",
    "Maserati": "15",
    "Mazda":    "16",
   "Mercedes - Benz": "17",
    "Mitsubishi":"18",
    "Nissan":   "19",
    "Opel":     "20",
    "Peugeot":  "21",
    "Porsche":  "22",
    "Renault":  "23",
    "Rover":    "24",
    "Saab":     "25",
    "Seat":     "26",
    "Skoda":    "27",
    "Subaru":   "28",
    "Suzuki":   "29",
    "Tata":     "30",
    "Tofaþ":    "31",
    "Toyota":   "32",
    "Volkswagen":"33",
    "Volvo":    "34"
}
combobox_1 = Combobox(
    master=root,
    textvariable=variable_1, state="readonly"
)
combobox_1['values']=sorted(list(values_1.keys()))

combobox_1.grid(column=20, row=0,padx=(500, 0),pady=(20, 20))
combobox_1.current(0)

label3 = Label( root, text = "SERİ:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label3.grid(column=20, row=1,padx=(500, 200),pady=(20, 20))
variable_2 =StringVar()
variable_2.set("Seri Seçin")
values_2 = {
    "Mercedes - Benz": ['200', '230', '250', '260', '280', '300', 'C', 'CLA', 'E', 'SLK'], 
    "BMW": ['3 Serisi', '5 Serisi'],
    "Alfa Romeo":['145'],
    'Audi':['80 Serisi', '90 Serisi', 'A1', 'A3', 'A4', 'A6'],
    'BMW':['3 Serisi', '5 Serisi'],
    'Chevrolet':['Aveo', 'Camaro', 'Cruze', 'Kalos', 'Lacetti'],
    'Citroen':['C-Elysee', 'C2', 'C3', 'C3 Picasso', 'C4', 'C4 Picasso', 'C5', 'Saxo', 'Xantia', 'Xsara'],
    'Dacia':['Lodgy', 'Logan', 'Sandero', 'Solenza'],
    'Renault':['Clio', 'Espace', 'Fluence', 'Grand Scenic', 'Laguna', 'Latitude', 'Megane', 'Modus', 'R 11', 'R 12', 'R 19', 'R 5', 'R 9', 'Safrane', 'Scenic', 'Symbol', 'Talisman'],
    'Tofaþ':['Doðan', 'Kartal', 'Þahin'],
    'Volkswagen':['Bora', 'Golf', 'Jetta', 'Lupo', 'Passat', 'Passat Variant', 'Polo', 'Santana', 'Scirocco', 'Touran', 'VW CC', 'Vento'], 
    'Seat':['Altea', 'Ibiza', 'Leon', 'Toledo'],
    'Opel':['Ascona', 'Astra', 'Calibra', 'Corsa', 'Insignia', 'Kadett', 'Meriva', 'Omega', 'Rekord', 'Tigra', 'Vectra', 'Zafira'], 
    'Volvo':['C30', 'S40', 'S60', 'S80', 'V40', 'V40 Cross Country', 'V50', 'V60'], 
    'Ford':['B-Max', 'C-Max', 'Escort', 'Fiesta', 'Focus', 'Fusion', 'Mondeo', 'S-Max', 'Scorpio', 'Sierra', 'Taunus'], 
    'Peugeot':['107', '206', '206+', '207', '208', '301', '306', '307', '308', '405', '407', '508', '807'], 
    'Hyundai':['Accent', 'Accent Blue', 'Accent Era', 'Elantra', 'Excel', 'Getz', 'Matrix', 'Sonata', 'i10', 'i20', 'i30'], 
    'Fiat':['Albea', 'Brava', 'Bravo', 'Egea', 'Idea', 'Linea', 'Marea', 'Palio', 'Panda', 'Punto', 'Siena', 'Tempra', 'Tipo', 'Uno'], 
    'Honda':['Accord', 'City', 'Civic'], 
    'Skoda':['Fabia', 'Favorit', 'Felicia', 'Octavia', 'Rapid', 'Roomster', 'SuperB'], 
    'Toyota':['Auris', 'Avensis', 'Carina', 'Corolla', 'Cressida', 'Verso', 'Yaris'], 
    'Lada':['Kalina', 'Samara', 'Vega'], 
    'Kia':['Cooper', 'Cooper Clubman', 'Cooper S', 'One'],
    'Nissan':['Almera', 'Laurel Altima', 'Micra', 'NX Coupe', 'Primera', 'Sunny'], 
    'MINI':['Cooper', 'Cooper Clubman', 'Cooper S', 'One'], 
    'Mitsubishi':['Carisma', 'Galant', 'Lancer'], 
    'Tata':['Indica'],
    'Mazda':['3', '323', '6', '626', 'Lantis', 'MPV'], 
    'Saab':['9000'], 
    'Daewoo':['Lanos', 'Nubira'], 
    'Rover':['25', '45'], 
    'Subaru':['Impreza', 'Legacy', 'Leone'], 
    'Porsche':['Panamera'], 
    'Maserati':['Ghibli'], 
    'Infiniti':['Q50'], 
    'Suzuki':['Swift']
    
}
combobox_2 = Combobox(
    master=root,
    textvariable=variable_2,
    values=values_2["Suzuki"], state="readonly"
)

combobox_2.grid(column=20, row=1,padx=(500, 0),pady=(20, 20))

variable_3 =StringVar()
variable_3.set("Model Seçin")
values_3 = {
    '145':['1.6'],
'80 Serisi':['1.6', '1.6 D', '2.0'],
'90 Serisi':['2.0'],
'A1':['1.6 TDI Ambition'],
'A3':['A3 Sedan 1.6 TDI Attraction'],
'A4':['A4 Sedan 2.0 TDI'],
'A6':['A6 Sedan 2.0 TDI'],
'3 Serisi':['316i Comfort', '316i Standart', '318i Standart', '320d M Sport', '320d Premium', '320d Standart', '320i', '320i ED Sport Line'],
'5 Serisi':['520d Premium', '520i Premium', '520i Standart'],
'Aveo':['1.2 S', '1.4 S', '1.4 SE', '1.4 SX'],
'Camaro':['2.0'],
'Cruze':['1.4 T Sport', '1.6', '1.6 LS', '1.6 LS Plus', '1.6 Sport'],
'Kalos':['1.2 S', '1.4 SE', '1.4 SX'],
'Lacetti':['1.4 SE', '1.4 SX', '1.6 SX'],
'C-Elysee':['1.6 HDi Attraction', '1.6 HDi Confort', '1.6 HDi Exclusive', '1.6 HDi Live'],
'C2':['1.4 SX'],
'C3':['1.4 Comfort', '1.4 SX', '1.6 HDi Exclusive', '1.6 HDi SX', '1.6 SX'],
'C3 Picasso':['1.4 SX', '1.6 HDi SX', '1.6 e-HDi Confort'],
'C4':['1.4 SX', '1.6 HDi Attraction', '1.6 HDi Confort', '1.6 HDi SX', '1.6 HDi SX PK', '1.6 SX', '1.6 e-HDi Confort'],
'C4 Picasso':['1.6 HDi SX', '1.6 HDi SX PK'],
'C5':['1.6 HDi Confort', '1.6 HDi SX', '1.6 HDi SX PK', '1.6 e-HDi Confort'],
'Saxo':['1.4 SX', '1.6 SX'],
'Xantia':['1.6 SX'],
'Xsara':['1.6 SX'],
'Lodgy':['1.5 dCi Laureate', '1.5 dCi Stepway'],
'Logan':['1.4', '1.4 Ambiance', '1.5 dCi Ambiance', '1.5 dCi Laureate', '1.5 dCi MCV Ambiance'],
'Sandero':['0.9 TCe Stepway Easy-R', '1.4 Ambiance', '1.5 dCi Ambiance', '1.5 dCi Stepway'],
'Solenza':['1.4 Comfort'],
'Lanos':['1.6 SX'],
'Nubira':['1.6 SX'],
'Albea':['1.2 Active', '1.2 Dynamic', '1.2 EL', '1.3 Multijet Active', '1.3 Multijet Dynamic', '1.4 Fire Active', '1.6 HL', 'Sole 1.3 Multijet Dynamic'],
'Brava':['1.6 ELX', '1.6 SX'],
'Bravo':['1.4 Fire Pop', '1.6 SX'],
'Egea':['1.3 Multijet Easy', '1.3 Multijet Urban', '1.3 Multijet Urban Plus', '1.4 Fire Easy', '1.4 Fire Easy Plus', '1.4 Fire Urban', '1.4 Fire Urban Plus', '1.6 Multijet Comfort', '1.6 Multijet Lounge', '1.6 Multijet Urban'],
'Idea':['1.3 Multijet Active', '1.3 Multijet Dynamic'],
'Linea':['1.3 Multijet Active', '1.3 Multijet Active Plus', '1.3 Multijet Dynamic', '1.3 Multijet Easy', '1.3 Multijet Pop', '1.3 Multijet Urban', '1.4 Fire Active', '1.4 Fire Easy', '1.4 Fire Pop', '1.6 Multijet Lounge', '1.6 Multijet Urban'],
'Marea':['1.6 ELX', '1.6 Liberty', '1.6 SX'],
'Palio':['1.2 Active', '1.2 Dynamic', '1.2 EL', '1.2 S', '1.3 Multijet Active', '1.3 Multijet Dynamic', '1.4 EL', '1.4 Fire Active', '1.6 HL'],
'Panda':['1.2 Active', '1.2 Dynamic'],
'Punto':['1.2 Dynamic', '1.3 Multijet Dynamic', '1.3 Multijet Easy', '1.3 Multijet Pop', '1.3 Multijet Urban', 'Grande 1.3 Multijet Active', 'Grande 1.4 Fire Active'],
'Siena':['1.2 EL', '1.2 S', '1.4 EL', '1.6 HL'],
'Tempra':['1.6 S', '1.6 SX', '1.6 SX A', '1.6 ie'],
'Tipo':['1.4 S', '1.4 SX', '1.6 S', '1.6 SLX', '1.6 SX', '1.6 ie'],
'Uno':['70 S', '70 SX'],
'B-Max':['1.4 Titanium', '1.5 TDCi Titanium', '1.5 TDCi Trend', '1.6 TDCi Titanium', '1.6 TDCi Trend', '1.6 Titanium', '1.6 Trend'],
'C-Max':['1.5 TDCi Titanium', '1.5 TDCi Trend', '1.6 Ghia', '1.6 TDCi Ghia', '1.6 TDCi Titanium', '1.6 TDCi Titanium X', '1.6 TDCi Trend', '1.6 Trend'],
'Escort':['1.6 CL', '1.6 CLX', '1.6 Classic', '1.6 Ghia'],
'Fiesta':['1.25 Trend', '1.25 Trend X', '1.4 Comfort', '1.4 TDCi Comfort', '1.4 TDCi Titanium', '1.4 TDCi Titanium X', '1.4 TDCi Trend', '1.4 Titanium', '1.4 Titanium X', '1.5 TDCi Titanium', '1.5 TDCi Titanium X', '1.5 TDCi Trend', '1.5 TDCi Trend X', '1.6 Collection', '1.6 Comfort', '1.6 Ghia', '1.6 Sport', '1.6 TDCi Ghia', '1.6 TDCi Titanium', '1.6 TDCi Titanium X', '1.6 Ti-VCT Titanium', '1.6 Ti-VCT Trend X', '1.6 Titanium', '1.6 Trend'],
'Focus':['1.4 Comfort', '1.5 TDCi Titanium', '1.5 TDCi Trend X', '1.5 Ti-VCT Trend X', '1.6 Ambiente', '1.6 Collection', '1.6 Comfort', '1.6 Ghia', '1.6 TDCi Collection', '1.6 TDCi Ghia', '1.6 TDCi Style', '1.6 TDCi Titanium', '1.6 TDCi Titanium X', '1.6 TDCi Trend', '1.6 TDCi Trend X', '1.6 Ti-VCT Style', '1.6 Ti-VCT Titanium', '1.6 Ti-VCT Trend X', '1.6 Titanium', '1.6 Trend', '2.0 Ghia'],
'Fusion':['1.4 TDCi Comfort', '1.6', '1.6 Comfort'],
'Mondeo':['1.6 TDCi Style', '1.6 TDCi Titanium', '1.6 TDCi Trend', '1.6 Ti-VCT Titanium', '1.6 Titanium', '1.6 Trend', '2.0 GLX', '2.0 Ghia'],
'S-Max':['1.6 TDCi Titanium'],
'Scorpio':['2.0 Ghia'],
'Sierra':['2.0 GLS'],
'Taunus':['1.6 GL', '1.6 S'],
'Accord':['2.0'],
'City':['1.4 Comfort'],
'Civic':['1.4 1.4i', '1.4 Comfort', '1.4 S', '1.5', '1.6 Dream', '1.6 Elegance', '1.6 GL', '1.6 LS', '1.6 Premium', '1.6 Sport', '1.6 i ES', '1.6 i-VTEC Dream', '1.6 i-VTEC ECO Elegance', '1.6 i-VTEC ES', '1.6 i-VTEC Eco Executive', '1.6 i-VTEC Eco Premium', '1.6 i-VTEC Elegance', '1.6 i-VTEC LS', '1.6 i-VTEC Premium'],
'Accent':['1.3 Admire', '1.3 GLS', '1.3 LS', '1.3 LX', '1.5 CRDi Admire', '1.5 GLS', '1.6 Admire'],
'Accent Blue':['1.4 D-CVVT Mode Plus', '1.6 CRDI Biz', '1.6 CRDI Mode', '1.6 CRDI Mode Plus'],
'Accent Era':['1.4 Start', '1.4 Team', '1.5 CRDi Team', '1.5 CRDi-VGT Team'],
'Elantra':['1.6 CRDi Elite', '1.6 CRDi Style', '1.6 D-CVVT Style', '1.6 Elegance', '1.6 GL', '1.6 GLS'],
'Excel':['1.5 GLS'],
'Getz':['1.3 GLS', '1.4 DOHC AB AC', '1.4 DOHC Start', '1.5 CRDi VGT'],
'Matrix':['1.5 CRDi Team', '1.6 GLS'],
'Sonata':['2.0', '2.0 GLS'],
'i10':['1.2 MPI Style'],
'i20':['1.2 D-CVVT Jump', '1.2 MPI Jump', '1.2 MPI Style', '1.4 CRDi Jump', '1.4 CRDi Style', '1.4 MPI Elite', '1.4 MPI Jump', '1.4 MPI Style'],
'i30':['1.6 CRDi Elite', '1.6 CRDi Style'],
'Q50':['2.0'],
'Ceed':['1.6 CRDi Concept Plus'],
'Cerato':['1.6 CRDi Concept Plus'],
'Sephia':['1.6 SLX'],
'Kalina':['1.6'],
'Samara':['1.5'],
'Vega':['1.5', '1.6'],
'Cooper':['1.6', '1.6 D'],
'Cooper Clubman':['1.6', '1.6 S'],
'Cooper S':['1.6'],
'One':['1.4', '1.6'],
'Ghibli':['2.0'],
'3':['1.6 Comfort'],
'323':['1.5', '1.6'],
'6':['2.0'],
'626':['1.6', '2.0', '2.0 GLX'],
'Lantis':['1.6'],
'MPV':['2.0'],
'200':['D', 'E'],
'230':['E'],
'250':['D'],
'260':['E'],
'280':['S'],
'300':['D', 'E'],
'C':['C 180 AMG 7G-Tronic', 'C 200 d BlueTEC AMG'],
'CLA':['180 D AMG', '200 AMG'],
'E':['200', '200 AMG', '200 Avantgarde'],
'SLK':['200'],
'Carisma':['1.6 Classic', '1.6 Comfort', '1.6 GL'],
'Galant':['1.6 GL'],
'Lancer':['1.6 Comfort'],
'Almera':['1.6 SLX'],
'Laurel Altima':['2.0'],
'Micra':['1.2 Match'],
'NX Coupe':['1.6'],
'Primera':['1.6', '1.6 Comfort', '1.6 SLX'],
'Sunny':['1.6 SLX'],
'Ascona':['1.6 D', '1.6 LS'],
'Clio':['0.9 TCe Joy', '1.0 SCe Joy', '1.0 TCe Joy', '1.0 TCe Touch', '1.2 Authentique', '1.2 Dynamic', '1.2 Expression', '1.2 Extreme', '1.2 Icon', '1.2 Joy', '1.4', '1.4 Alize', '1.4 Authentique', '1.4 Expression', '1.4 RNA', '1.4 RTA', '1.5 dCi Alize', '1.5 dCi Authentique', '1.5 dCi Dynamique', '1.5 dCi Expression', '1.5 dCi Extreme', '1.5 dCi Icon', '1.5 dCi Joy', '1.5 dCi SportTourer Joy', '1.5 dCi Touch', '1.6 Dynamique', '1.6 Extreme', '1.6 RTE', '1.6 RXT'],
'Espace':['2.0 RXE'],
'Fluence':['1.5 dCi Authentique', '1.5 dCi Business', '1.5 dCi Dynamique', '1.5 dCi Expression', '1.5 dCi Extreme', '1.5 dCi Icon', '1.5 dCi Joy', '1.5 dCi Privilege', '1.5 dCi Touch', '1.5 dCi Touch Plus', '1.6 Authentique', '1.6 Dynamique', '1.6 Expression', '1.6 Extreme', '1.6 Joy', '1.6 Privilege', '1.6 Touch'],
'Grand Scenic':['1.5 dCi Authentique', '1.5 dCi Icon', '1.5 dCi Privilege', '1.6 Privilege'],
'Laguna':['1.5 dCi Authentique', '1.5 dCi Dynamique', '1.5 dCi Expression', '1.5 dCi Privilege', '1.6', '1.6 Authentique', '1.6 Dynamique', '1.6 Expression', '1.6 Privilege', '2.0 RXE', '2.0 RXT'],
'Latitude':['1.5 dCi Expression', '1.5 dCi Privilege'],
'Megane':['1.3 Tce Joy', '1.4', '1.4 Alize', '1.4 Authentique', '1.4 Expression', '1.4 RTA', '1.5 Blue DCI Touch', '1.5 dCi Authentique', '1.5 dCi Business', '1.5 dCi Dynamique', '1.5 dCi Expression', '1.5 dCi Extreme', '1.5 dCi Icon', '1.5 dCi Joy', '1.5 dCi Privilege', '1.5 dCi Touch', '1.5 dCi Touch Plus', '1.6', '1.6 Authentique', '1.6 Dynamique', '1.6 Expression', '1.6 Extreme', '1.6 Joy', '1.6 Privilege', '1.6 RTE', '1.6 RXT', '1.6 Touch', '2.0 RXE', '2.0 RXT'],
'Modus':['1.4 Authentique', '1.5 dCi Authentique', '1.5 dCi Dynamique', '1.6 Authentique', '1.6 Dynamique'],
'R 11':['TX'],
'R 12':['TX', 'Toros'],
'R 19':['1.4 1.4i', '1.6', '1.6 Europa RNE', '1.6 Europa RT', '1.6 Europa RTE'],
'R 5':['1.4'],
'R 9':['1.4', '1.4 Broadway', '1.4 Broadway GTE', '1.4 Broadway RN', '1.4 Broadway RNi', '1.4 Spring'],
'Safrane':['2.0', '2.0 RXE'],
'Scenic':['1.5 dCi Authentique', '1.5 dCi Expression', '1.5 dCi Icon', '1.5 dCi Privilege', '1.5 dCi Touch', '1.6 Authentique', '1.6 Dynamique', '1.6 Privilege', '1.6 RTE', '1.6 RXT', '2.0 RXT'],
'Symbol':['0.9 TCe Joy', '1.0 SCe Joy', '1.0 TCe Joy', '1.2 Authentique', '1.2 Expression', '1.2 Extreme', '1.2 Joy', '1.4 Authentique', '1.4 Expression', '1.5 dCi Authentique', '1.5 dCi Dynamique', '1.5 dCi Expression', '1.5 dCi Extreme', '1.5 dCi Joy', '1.5 dCi Touch', '1.6 Authentique'],
'Talisman':['1.5 dCi Icon', '1.5 dCi Touch'],
'25':['1.6 Classic'],
'45':['1.6 Classic'],
'9000':['2.0'],
'Altea':['1.6 Stylance'],
'Ibiza':['1.2 TSI Style', '1.4 Reference', '1.4 SE', '1.6 Elegance', '1.6 Sport', '1.6 TDI Style'],
'Leon':['1.2 TSI Style', '1.4 TSI FR', '1.6 Sport', '1.6 Stylance', '1.6 TDI CR Style', '1.6 TDI Style'],
'Toledo':['1.2 TSI Style', '1.6 TDI Style'],
'Fabia':['1.2 TSI Style', '1.4 Classic', '1.4 Comfort', '1.6 Ambiente', '1.6 TDI Ambition', '1.6 TDI Optimal'],
'Favorit':['1.3 LX'],
'Felicia':['1.3 LX'],
'Octavia':['1.2 TSI Style', '1.6 Ambiente', '1.6 Classic', '1.6 Elegance', '1.6 TDI Ambition', '1.6 TDI Elegance', '1.6 TDI Elegance CR', '1.6 TDI Optimal', '1.6 TDI Style', '1.6 TDI Style CR'],
'Rapid':['1.2 Active', '1.6 TDI Ambition', '1.6 TDI Elegance'],
'Roomster':['1.2 Active', '1.4 Comfort', '1.6 TDI Style'],
'SuperB':['1.6 TDI Ambition', '1.6 TDI Elegance', '1.6 TDI Prestige', '1.6 TDI Style'],
'Impreza':['1.6 GL'],
'Legacy':['2.0'],
'Leone':['1.6'],
'Swift':['1.3 GLS'],
'Indica':['1.4 Comfort'],
'Doðan':['1.6', '1.6 ie', 'L', 'S', 'SL', 'SLX', 'SLX ie'],
'Kartal':['1.6', '1.6 ie', 'Kartal 5 Vites', 'S', 'SL', 'SLX', 'SLX ie'],
'Þahin':['1.4', '1.6', '1.6 ie', 'S', 'Þahin 5 Vites'],
'Auris':['1.33 Comfort', '1.33 Life', '1.4 D-4D Advance', '1.4 D-4D Comfort', '1.4 D-4D Comfort Extra', '1.4 D-4D Elegant', '1.4 D-4D Premium', '1.4 D-4D Touch', '1.6 Advance', '1.6 Comfort', '1.6 Comfort Extra', '1.6 Elegant', '1.6 Premium', '1.6 Sport', '1.6 Touch'],
'Avensis':['1.6', '1.6 Advance', '1.6 Comfort', '1.6 Elegant', '1.6 Elegant Extra', '1.6 Premium'],
'Carina':['2.0'],
'Corolla':['1.3 XL', '1.33 Comfort', '1.33 Life', '1.4', '1.4 D-4D Advance', '1.4 D-4D Comfort', '1.4 D-4D Comfort Extra', '1.4 D-4D Elegant', '1.4 D-4D Premium', '1.4 D-4D Terra', '1.4 D-4D Touch', '1.5 Dream', '1.6', '1.6 Advance', '1.6 Comfort', '1.6 Comfort Extra', '1.6 Dream', '1.6 Elegant', '1.6 GL', '1.6 GLi', '1.6 Life', '1.6 Premium', '1.6 Sol', '1.6 Sport', '1.6 Terra', '1.6 Touch', '1.6 Vision', '1.6 XEi'],
'Cressida':['2.0', '2.0 GLX'],
'Verso':['1.6 Comfort Extra', '1.6 Elegant', '1.6 Premium'],
'Yaris':['1.0 Life', '1.4 D-4D Terra', '1.5 Dream'],
'Bora':['1.6 Comfortline', '1.6 Pacific', '1.6 Primeline', '1.6 Trendline', '1.9 TDi Comfortline'],
'Golf':['1.2 TSi Comfortline', '1.2 TSi Midline Plus', '1.4 TSi Comfortline', '1.4 TSi Highline', '1.4 TSi Trendline', '1.6', '1.6 CL', '1.6 Comfortline', '1.6 FSi Comfortline', '1.6 FSi Midline', '1.6 GL', '1.6 Midline', '1.6 Pacific', '1.6 Premium', '1.6 Primeline', '1.6 Sport', '1.6 TDi BlueMotion Comfortline', '1.6 TDi BlueMotion Highline', '1.6 TDi BlueMotion Midline Plus', '1.6 TDi Comfortline', '1.6 TDi Highline', '1.6 TDi Trendline', '1.6 Trendline', '1.8 GL', '1.9 TDi Comfortline', '2.0 TDi Comfortline'],
'Jetta':['1.2 TSi BlueMotion Comfortline', '1.2 TSi Comfortline', '1.2 TSi Trendline', '1.4 TSi BlueMotion Comfortline', '1.4 TSi BlueMotion Highline', '1.4 TSi BlueMotion Trendline', '1.4 TSi Comfortline', '1.4 TSi Highline', '1.4 TSi Trendline', '1.6', '1.6 CL', '1.6 Comfortline', '1.6 FSi Comfortline', '1.6 FSi Midline', '1.6 GL', '1.6 Midline', '1.6 Primeline', '1.6 TDi Comfortline', '1.6 TDi Highline', '1.6 TDi Trendline', '2.0 TDi Comfortline'],
'Lupo':['1.4 Trendline'],
'Passat':['1.4 TSi BlueMotion Comfortline', '1.4 TSi BlueMotion Highline', '1.4 TSi BlueMotion Trendline', '1.4 TSi Comfortline', '1.4 TSi Highline', '1.4 TSi Trendline', '1.5 TSi Business', '1.6', '1.6 CL', '1.6 Comfortline', '1.6 FSi Comfortline', '1.6 TDi BlueMotion Comfortline', '1.6 TDi BlueMotion Highline', '1.6 TDi BlueMotion Impression', '1.6 TDi BlueMotion Trendline', '1.6 TDi Comfortline', '1.6 Trendline', '1.8 T Comfortline', '1.9 TDi Comfortline', '2.0 TDi BlueMotion Comfortline', '2.0 TDi BlueMotion Highline', '2.0 TDi Comfortline'],
'Passat Variant':['1.4 TSi BlueMotion Comfortline', '1.4 TSi BlueMotion Highline', '1.4 TSi Comfortline', '1.6 FSi Comfortline', '1.6 TDi BlueMotion Comfortline', '1.6 TDi BlueMotion Highline', '1.6 TDi Comfortline', '1.6 TDi Highline', '1.9 TDi Comfortline', '2.0 TDi Comfortline'],
'Polo':['1.0 Comfortline', '1.0 Life', '1.2 TDi Trendline', '1.2 TSi Comfortline', '1.2 Trendline', '1.4', '1.4 Basicline', '1.4 Comfortline', '1.4 TDi Comfortline', '1.4 TDi Trendline', '1.4 Trendline', '1.6', '1.6 Classic', '1.6 Comfortline', '1.6 TDi Comfortline', '1.6 TDi Highline', '1.6 TDi Trendline'],
'Santana':['1.6'],
'Scirocco':['1.4 TSi Sportline'],
'Touran':['1.4 TSi Comfortline', '1.6 Comfortline', '1.6 FSi Comfortline', '1.6 Trendline', '1.9 TDi Comfortline'],
'VW CC':['1.4 TSi'],
'Vento':['1.6 CL', '1.6 GL'],
'C30':['1.6', '1.6 D Advance', '1.6 D Premium'],
'S40':['1.6', '1.6 D', '1.6 D Premium', '1.6 Premium', '2.0'],
'S60':['1.6 D', '1.6 D Advance', '1.6 D Premium'],
'S80':['1.6 D', '1.6 D Advance', '1.6 D Premium'],
'V40':['1.6', '1.6 D Advance', '1.6 D Premium', '2.0'],
'V40 Cross Country':['1.6 D Advance', '1.6 D Premium'],
'V50':['1.6', '1.6 D'],
'V60':['1.6 D Advance']

}

label4 = Label( root, text = "MODEL:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label4.grid(column=20, row=2,padx=(500, 210),pady=(20, 20))

combobox_3 = Combobox(
    master=root,
    textvariable=variable_3,
    values=values_3["80 Serisi"], state="readonly"
)
combobox_3.current(0)
combobox_3.grid(column=20, row=2,padx=(500, 0),pady=(10, 10))

combobox_2.bind("<<ComboboxSelected>>", lambda event: changemodel())
def changeseri():
    if combobox_1.get() == "Mercedes - Benz":
        combobox_2.configure(values=values_2["Mercedes - Benz"])
    elif combobox_1.get() == "BMW":
        combobox_2.configure(values=values_2["BMW"])
    elif combobox_1.get() == "Alfa Romeo":
        combobox_2.configure(values=values_2["Alfa Romeo"])
    elif combobox_1.get() == "Chevrolet":
        combobox_2.configure(values=values_2["Chevrolet"])
    elif combobox_1.get() == "Citroen":
        combobox_2.configure(values=values_2["Citroen"])
    elif combobox_1.get() == "Dacia ":
        combobox_2.configure(values=values_2["Dacia "])
    elif combobox_1.get() == "Renault":
        combobox_2.configure(values=values_2["Renault"])
    elif combobox_1.get() == "Tofaþ":
        combobox_2.configure(values=values_2["Tofaþ"])
    elif combobox_1.get() == "Volkswagen":
        combobox_2.configure(values=values_2["Volkswagen"])    
    elif combobox_1.get() == "Seat":
        combobox_2.configure(values=values_2["Seat"])
    elif combobox_1.get() == "Opel":
        combobox_2.configure(values=values_2["Opel"])
    elif combobox_1.get() == "Peugeot":
        combobox_2.configure(values=values_2["Peugeot"])
    elif combobox_1.get() == "Ford":
        combobox_2.configure(values=values_2["Ford"])    
    elif combobox_1.get() == "Volvo":
        combobox_2.configure(values=values_2["Volvo"])
    elif combobox_1.get() == "Hyundai":
        combobox_2.configure(values=values_2["Hyundai"])
    elif combobox_1.get() == "Fiat":
        combobox_2.configure(values=values_2["Fiat"])
    elif combobox_1.get() == "Honda":
        combobox_2.configure(values=values_2["Honda"])    
    elif combobox_1.get() == "Skoda":
        combobox_2.configure(values=values_2["Skoda"])
    elif combobox_1.get() == "Toyota":
        combobox_2.configure(values=values_2["Toyota"])
    elif combobox_1.get() == "Lada":
        combobox_2.configure(values=values_2["Lada"])
    elif combobox_1.get() == "Kia":
        combobox_2.configure(values=values_2["Kia"])    
    elif combobox_1.get() == "Audi":
        combobox_2.configure(values=values_2["Audi"])
    elif combobox_1.get() == "Nissan":
        combobox_2.configure(values=values_2["Nissan"])
    elif combobox_1.get() == "MINI":
        combobox_2.configure(values=values_2["MINI"])
    elif combobox_1.get() == "Mitsubishi":
        combobox_2.configure(values=values_2["Mitsubishi"])    
    elif combobox_1.get() == "Tata":
        combobox_2.configure(values=values_2["Tata"])
    elif combobox_1.get() == "Mazda":
        combobox_2.configure(values=values_2["Mazda"])
    elif combobox_1.get() == "Saab":
        combobox_2.configure(values=values_2["Saab"])
    elif combobox_1.get() == "Daewoo":
        combobox_2.configure(values=values_2["Daewoo"])    
    elif combobox_1.get() == "BMW":
        combobox_2.configure(values=values_2["BMW"])
    elif combobox_1.get() == "Rover":
        combobox_2.configure(values=values_2["Rover"])
    elif combobox_1.get() == "Subaru":
        combobox_2.configure(values=values_2["Subaru"])
    elif combobox_1.get() == "Porsche":
        combobox_2.configure(values=values_2["Porsche"])    
    elif combobox_1.get() == "Maserati":
        combobox_2.configure(values=values_2["Maserati"])
    elif combobox_1.get() == "Infiniti":
        combobox_2.configure(values=values_2["Infiniti"])
    elif combobox_1.get() == "Suzuki":
        combobox_2.configure(values=values_2["Suzuki"])       
def changemodel():
    if combobox_2.get() == '145':
        combobox_3.configure(values=values_2['145'])
    elif combobox_2.get() =='80 Serisi':
          combobox_3.configure(values=values_3['80 Serisi'])


    elif combobox_2.get() =='90 Serisi':
          combobox_3.configure(values=values_3['90 Serisi'])


    elif combobox_2.get() =='A1':
          combobox_3.configure(values=values_3['A1'])


    elif combobox_2.get() =='A3':
          combobox_3.configure(values=values_3['A3'])


    elif combobox_2.get() =='A4':
          combobox_3.configure(values=values_3['A4'])


    elif combobox_2.get() =='A6':
          combobox_3.configure(values=values_3['A6'])


    elif combobox_2.get() =='3 Serisi':
          combobox_3.configure(values=values_3['3 Serisi'])


    elif combobox_2.get() =='5 Serisi':
          combobox_3.configure(values=values_3['5 Serisi'])


    elif combobox_2.get() =='Aveo':
          combobox_3.configure(values=values_3['Aveo'])


    elif combobox_2.get() =='Camaro':
          combobox_3.configure(values=values_3['Camaro'])


    elif combobox_2.get() =='Cruze':
          combobox_3.configure(values=values_3['Cruze'])


    elif combobox_2.get() =='Kalos':
          combobox_3.configure(values=values_3['Kalos'])


    elif combobox_2.get() =='Lacetti':
          combobox_3.configure(values=values_3['Lacetti'])


    elif combobox_2.get() =='C-Elysee':
          combobox_3.configure(values=values_3['C-Elysee'])


    elif combobox_2.get() =='C2':
          combobox_3.configure(values=values_3['C2'])


    elif combobox_2.get() =='C3':
          combobox_3.configure(values=values_3['C3'])


    elif combobox_2.get() =='C3 Picasso':
          combobox_3.configure(values=values_3['C3 Picasso'])


    elif combobox_2.get() =='C4':
          combobox_3.configure(values=values_3['C4'])


    elif combobox_2.get() =='C4 Picasso':
          combobox_3.configure(values=values_3['C4 Picasso'])


    elif combobox_2.get() =='C5':
          combobox_3.configure(values=values_3['C5'])


    elif combobox_2.get() =='Saxo':
          combobox_3.configure(values=values_3['Saxo'])


    elif combobox_2.get() =='Xantia':
          combobox_3.configure(values=values_3['Xantia'])


    elif combobox_2.get() =='Xsara':
          combobox_3.configure(values=values_3['Xsara'])


    elif combobox_2.get() =='Lodgy':
          combobox_3.configure(values=values_3['Lodgy'])


    elif combobox_2.get() =='Logan':
          combobox_3.configure(values=values_3['Logan'])


    elif combobox_2.get() =='Sandero':
          combobox_3.configure(values=values_3['Sandero'])


    elif combobox_2.get() =='Solenza':
          combobox_3.configure(values=values_3['Solenza'])


    elif combobox_2.get() =='Lanos':
          combobox_3.configure(values=values_3['Lanos'])


    elif combobox_2.get() =='Nubira':
          combobox_3.configure(values=values_3['Nubira'])


    elif combobox_2.get() =='Albea':
          combobox_3.configure(values=values_3['Albea'])


    elif combobox_2.get() =='Brava':
          combobox_3.configure(values=values_3['Brava'])


    elif combobox_2.get() =='Bravo':
          combobox_3.configure(values=values_3['Bravo'])


    elif combobox_2.get() =='Egea':
          combobox_3.configure(values=values_3['Egea'])


    elif combobox_2.get() =='Idea':
          combobox_3.configure(values=values_3['Idea'])


    elif combobox_2.get() =='Linea':
          combobox_3.configure(values=values_3['Linea'])


    elif combobox_2.get() =='Marea':
          combobox_3.configure(values=values_3['Marea'])


    elif combobox_2.get() =='Palio':
          combobox_3.configure(values=values_3['Palio'])


    elif combobox_2.get() =='Panda':
          combobox_3.configure(values=values_3['Panda'])


    elif combobox_2.get() =='Punto':
          combobox_3.configure(values=values_3['Punto'])


    elif combobox_2.get() =='Siena':
          combobox_3.configure(values=values_3['Siena'])


    elif combobox_2.get() =='Tempra':
          combobox_3.configure(values=values_3['Tempra'])


    elif combobox_2.get() =='Tipo':
          combobox_3.configure(values=values_3['Tipo'])


    elif combobox_2.get() =='Uno':
          combobox_3.configure(values=values_3['Uno'])


    elif combobox_2.get() =='B-Max':
          combobox_3.configure(values=values_3['B-Max'])


    elif combobox_2.get() =='C-Max':
          combobox_3.configure(values=values_3['C-Max'])


    elif combobox_2.get() =='Escort':
          combobox_3.configure(values=values_3['Escort'])


    elif combobox_2.get() =='Fiesta':
          combobox_3.configure(values=values_3['Fiesta'])


    elif combobox_2.get() =='Focus':
          combobox_3.configure(values=values_3['Focus'])


    elif combobox_2.get() =='Fusion':
          combobox_3.configure(values=values_3['Fusion'])


    elif combobox_2.get() =='Mondeo':
          combobox_3.configure(values=values_3['Mondeo'])


    elif combobox_2.get() =='S-Max':
          combobox_3.configure(values=values_3['S-Max'])


    elif combobox_2.get() =='Scorpio':
          combobox_3.configure(values=values_3['Scorpio'])


    elif combobox_2.get() =='Sierra':
          combobox_3.configure(values=values_3['Sierra'])


    elif combobox_2.get() =='Taunus':
          combobox_3.configure(values=values_3['Taunus'])


    elif combobox_2.get() =='Accord':
          combobox_3.configure(values=values_3['Accord'])


    elif combobox_2.get() =='City':
          combobox_3.configure(values=values_3['City'])


    elif combobox_2.get() =='Civic':
          combobox_3.configure(values=values_3['Civic'])


    elif combobox_2.get() =='Accent':
          combobox_3.configure(values=values_3['Accent'])


    elif combobox_2.get() =='Accent Blue':
          combobox_3.configure(values=values_3['Accent Blue'])


    elif combobox_2.get() =='Accent Era':
          combobox_3.configure(values=values_3['Accent Era'])


    elif combobox_2.get() =='Elantra':
          combobox_3.configure(values=values_3['Elantra'])


    elif combobox_2.get() =='Excel':
          combobox_3.configure(values=values_3['Excel'])


    elif combobox_2.get() =='Getz':
          combobox_3.configure(values=values_3['Getz'])


    elif combobox_2.get() =='Matrix':
          combobox_3.configure(values=values_3['Matrix'])


    elif combobox_2.get() =='Sonata':
          combobox_3.configure(values=values_3['Sonata'])


    elif combobox_2.get() =='i10':
          combobox_3.configure(values=values_3['i10'])


    elif combobox_2.get() =='i20':
          combobox_3.configure(values=values_3['i20'])


    elif combobox_2.get() =='i30':
          combobox_3.configure(values=values_3['i30'])


    elif combobox_2.get() =='Q50':
          combobox_3.configure(values=values_3['Q50'])


    elif combobox_2.get() =='Ceed':
          combobox_3.configure(values=values_3['Ceed'])


    elif combobox_2.get() =='Cerato':
          combobox_3.configure(values=values_3['Cerato'])


    elif combobox_2.get() =='Sephia':
          combobox_3.configure(values=values_3['Sephia'])


    elif combobox_2.get() =='Kalina':
          combobox_3.configure(values=values_3['Kalina'])


    elif combobox_2.get() =='Samara':
          combobox_3.configure(values=values_3['Samara'])


    elif combobox_2.get() =='Vega':
          combobox_3.configure(values=values_3['Vega'])


    elif combobox_2.get() =='Cooper':
          combobox_3.configure(values=values_3['Cooper'])


    elif combobox_2.get() =='Cooper Clubman':
          combobox_3.configure(values=values_3['Cooper Clubman'])


    elif combobox_2.get() =='Cooper S':
          combobox_3.configure(values=values_3['Cooper S'])


    elif combobox_2.get() =='One':
          combobox_3.configure(values=values_3['One'])


    elif combobox_2.get() =='Ghibli':
          combobox_3.configure(values=values_3['Ghibli'])


    elif combobox_2.get() =='3':
          combobox_3.configure(values=values_3['3'])


    elif combobox_2.get() =='323':
          combobox_3.configure(values=values_3['323'])


    elif combobox_2.get() =='6':
          combobox_3.configure(values=values_3['6'])


    elif combobox_2.get() =='626':
          combobox_3.configure(values=values_3['626'])


    elif combobox_2.get() =='Lantis':
          combobox_3.configure(values=values_3['Lantis'])


    elif combobox_2.get() =='MPV':
          combobox_3.configure(values=values_3['MPV'])


    elif combobox_2.get() =='200':
          combobox_3.configure(values=values_3['200'])


    elif combobox_2.get() =='230':
          combobox_3.configure(values=values_3['230'])


    elif combobox_2.get() =='250':
          combobox_3.configure(values=values_3['250'])


    elif combobox_2.get() =='260':
          combobox_3.configure(values=values_3['260'])


    elif combobox_2.get() =='280':
          combobox_3.configure(values=values_3['280'])


    elif combobox_2.get() =='300':
          combobox_3.configure(values=values_3['300'])


    elif combobox_2.get() =='C':
          combobox_3.configure(values=values_3['C'])


    elif combobox_2.get() =='CLA':
          combobox_3.configure(values=values_3['CLA'])


    elif combobox_2.get() =='E':
          combobox_3.configure(values=values_3['E'])


    elif combobox_2.get() =='SLK':
          combobox_3.configure(values=values_3['SLK'])


    elif combobox_2.get() =='Carisma':
          combobox_3.configure(values=values_3['Carisma'])


    elif combobox_2.get() =='Galant':
          combobox_3.configure(values=values_3['Galant'])


    elif combobox_2.get() =='Lancer':
          combobox_3.configure(values=values_3['Lancer'])


    elif combobox_2.get() =='Almera':
          combobox_3.configure(values=values_3['Almera'])


    elif combobox_2.get() =='Laurel Altima':
          combobox_3.configure(values=values_3['Laurel Altima'])


    elif combobox_2.get() =='Micra':
          combobox_3.configure(values=values_3['Micra'])


    elif combobox_2.get() =='NX Coupe':
          combobox_3.configure(values=values_3['NX Coupe'])


    elif combobox_2.get() =='Primera':
          combobox_3.configure(values=values_3['Primera'])


    elif combobox_2.get() =='Sunny':
          combobox_3.configure(values=values_3['Sunny'])


    elif combobox_2.get() =='Ascona':
          combobox_3.configure(values=values_3['Ascona'])


    elif combobox_2.get() =='Astra':
          combobox_3.configure(values=values_3['Astra'])


    elif combobox_2.get() =='Calibra':
          combobox_3.configure(values=values_3['Calibra'])


    elif combobox_2.get() =='Corsa':
          combobox_3.configure(values=values_3['Corsa'])


    elif combobox_2.get() =='Insignia':
          combobox_3.configure(values=values_3['Insignia'])


    elif combobox_2.get() =='Kadett':
          combobox_3.configure(values=values_3['Kadett'])


    elif combobox_2.get() =='Meriva':
          combobox_3.configure(values=values_3['Meriva'])


    elif combobox_2.get() =='Omega':
          combobox_3.configure(values=values_3['Omega'])


    elif combobox_2.get() =='Rekord':
          combobox_3.configure(values=values_3['Rekord'])


    elif combobox_2.get() =='Tigra':
          combobox_3.configure(values=values_3['Tigra'])


    elif combobox_2.get() =='Vectra':
          combobox_3.configure(values=values_3['Vectra'])


    elif combobox_2.get() =='Zafira':
          combobox_3.configure(values=values_3['Zafira'])


    elif combobox_2.get() =='107':
          combobox_3.configure(values=values_3['107'])


    elif combobox_2.get() =='206':
          combobox_3.configure(values=values_3['206'])


    elif combobox_2.get() =='206+':
          combobox_3.configure(values=values_3['206+'])


    elif combobox_2.get() =='207':
          combobox_3.configure(values=values_3['207'])


    elif combobox_2.get() =='208':
          combobox_3.configure(values=values_3['208'])


    elif combobox_2.get() =='301':
          combobox_3.configure(values=values_3['301'])


    elif combobox_2.get() =='306':
          combobox_3.configure(values=values_3['306'])


    elif combobox_2.get() =='307':
          combobox_3.configure(values=values_3['307'])


    elif combobox_2.get() =='308':
          combobox_3.configure(values=values_3['308'])


    elif combobox_2.get() =='405':
          combobox_3.configure(values=values_3['405'])


    elif combobox_2.get() =='407':
          combobox_3.configure(values=values_3['407'])


    elif combobox_2.get() =='508':
          combobox_3.configure(values=values_3['508'])


    elif combobox_2.get() =='807':
          combobox_3.configure(values=values_3['807'])


    elif combobox_2.get() =='Panamera':
          combobox_3.configure(values=values_3['Panamera'])


    elif combobox_2.get() =='Clio':
          combobox_3.configure(values=values_3['Clio'])


    elif combobox_2.get() =='Espace':
          combobox_3.configure(values=values_3['Espace'])


    elif combobox_2.get() =='Fluence':
          combobox_3.configure(values=values_3['Fluence'])


    elif combobox_2.get() =='Grand Scenic':
          combobox_3.configure(values=values_3['Grand Scenic'])


    elif combobox_2.get() =='Laguna':
          combobox_3.configure(values=values_3['Laguna'])


    elif combobox_2.get() =='Latitude':
          combobox_3.configure(values=values_3['Latitude'])


    elif combobox_2.get() =='Megane':
          combobox_3.configure(values=values_3['Megane'])


    elif combobox_2.get() =='Modus':
          combobox_3.configure(values=values_3['Modus'])


    elif combobox_2.get() =='R 11':
          combobox_3.configure(values=values_3['R 11'])


    elif combobox_2.get() =='R 12':
          combobox_3.configure(values=values_3['R 12'])


    elif combobox_2.get() =='R 19':
          combobox_3.configure(values=values_3['R 19'])


    elif combobox_2.get() =='R 5':
          combobox_3.configure(values=values_3['R 5'])


    elif combobox_2.get() =='R 9':
          combobox_3.configure(values=values_3['R 9'])


    elif combobox_2.get() =='Safrane':
          combobox_3.configure(values=values_3['Safrane'])


    elif combobox_2.get() =='Scenic':
          combobox_3.configure(values=values_3['Scenic'])


    elif combobox_2.get() =='Symbol':
          combobox_3.configure(values=values_3['Symbol'])


    elif combobox_2.get() =='Talisman':
          combobox_3.configure(values=values_3['Talisman'])


    elif combobox_2.get() =='25':
          combobox_3.configure(values=values_3['25'])


    elif combobox_2.get() =='45':
          combobox_3.configure(values=values_3['45'])


    elif combobox_2.get() =='9000':
          combobox_3.configure(values=values_3['9000'])


    elif combobox_2.get() =='Altea':
          combobox_3.configure(values=values_3['Altea'])


    elif combobox_2.get() =='Ibiza':
          combobox_3.configure(values=values_3['Ibiza'])


    elif combobox_2.get() =='Leon':
          combobox_3.configure(values=values_3['Leon'])


    elif combobox_2.get() =='Toledo':
          combobox_3.configure(values=values_3['Toledo'])


    elif combobox_2.get() =='Fabia':
          combobox_3.configure(values=values_3['Fabia'])


    elif combobox_2.get() =='Favorit':
          combobox_3.configure(values=values_3['Favorit'])


    elif combobox_2.get() =='Felicia':
          combobox_3.configure(values=values_3['Felicia'])


    elif combobox_2.get() =='Octavia':
          combobox_3.configure(values=values_3['Octavia'])


    elif combobox_2.get() =='Rapid':
          combobox_3.configure(values=values_3['Rapid'])


    elif combobox_2.get() =='Roomster':
          combobox_3.configure(values=values_3['Roomster'])


    elif combobox_2.get() =='SuperB':
          combobox_3.configure(values=values_3['SuperB'])


    elif combobox_2.get() =='Impreza':
          combobox_3.configure(values=values_3['Impreza'])


    elif combobox_2.get() =='Legacy':
          combobox_3.configure(values=values_3['Legacy'])


    elif combobox_2.get() =='Leone':
          combobox_3.configure(values=values_3['Leone'])


    elif combobox_2.get() =='Swift':
          combobox_3.configure(values=values_3['Swift'])


    elif combobox_2.get() =='Indica':
          combobox_3.configure(values=values_3['Indica'])


    elif combobox_2.get() =='Doðan':
          combobox_3.configure(values=values_3['Doðan'])


    elif combobox_2.get() =='Kartal':
          combobox_3.configure(values=values_3['Kartal'])


    elif combobox_2.get() =='Þahin':
          combobox_3.configure(values=values_3['Þahin'])


    elif combobox_2.get() =='Auris':
          combobox_3.configure(values=values_3['Auris'])


    elif combobox_2.get() =='Avensis':
          combobox_3.configure(values=values_3['Avensis'])


    elif combobox_2.get() =='Carina':
          combobox_3.configure(values=values_3['Carina'])


    elif combobox_2.get() =='Corolla':
          combobox_3.configure(values=values_3['Corolla'])


    elif combobox_2.get() =='Cressida':
          combobox_3.configure(values=values_3['Cressida'])


    elif combobox_2.get() =='Verso':
          combobox_3.configure(values=values_3['Verso'])


    elif combobox_2.get() =='Yaris':
          combobox_3.configure(values=values_3['Yaris'])


    elif combobox_2.get() =='Bora':
          combobox_3.configure(values=values_3['Bora'])


    elif combobox_2.get() =='Golf':
          combobox_3.configure(values=values_3['Golf'])


    elif combobox_2.get() =='Jetta':
          combobox_3.configure(values=values_3['Jetta'])


    elif combobox_2.get() =='Lupo':
          combobox_3.configure(values=values_3['Lupo'])


    elif combobox_2.get() =='Passat':
          combobox_3.configure(values=values_3['Passat'])


    elif combobox_2.get() =='Passat Variant':
          combobox_3.configure(values=values_3['Passat Variant'])


    elif combobox_2.get() =='Polo':
          combobox_3.configure(values=values_3['Polo'])


    elif combobox_2.get() =='Santana':
          combobox_3.configure(values=values_3['Santana'])


    elif combobox_2.get() =='Scirocco':
          combobox_3.configure(values=values_3['Scirocco'])


    elif combobox_2.get() =='Touran':
          combobox_3.configure(values=values_3['Touran'])


    elif combobox_2.get() =='VW CC':
          combobox_3.configure(values=values_3['VW CC'])


    elif combobox_2.get() =='Vento':
          combobox_3.configure(values=values_3['Vento'])


    elif combobox_2.get() =='C30':
          combobox_3.configure(values=values_3['C30'])


    elif combobox_2.get() =='S40':
          combobox_3.configure(values=values_3['S40'])


    elif combobox_2.get() =='S60':
          combobox_3.configure(values=values_3['S60'])


    elif combobox_2.get() =='S80':
          combobox_3.configure(values=values_3['S80'])


    elif combobox_2.get() =='V40':
          combobox_3.configure(values=values_3['V40'])


    elif combobox_2.get() =='V40 Cross Country':
          combobox_3.configure(values=values_3['V40 Cross Country'])


    elif combobox_2.get() =='V50':
          combobox_3.configure(values=values_3['V50'])


    elif combobox_2.get() =='V60':
          combobox_3.configure(values=values_3['V60'])
        
        
combobox_1.bind("<<ComboboxSelected>>", lambda event: changeseri())


label5 = Label( root, text = "YAKIT:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label5.grid(column=20, row=3,padx=(500, 210),pady=(20, 20))
yakit={
    'Dizel':"1",
    'LPG & Benzin':"4", 
    'Benzin':"0", 
    'Hibrit':"3", 
    'Elektrik':"2"
      }
comboboxyakit=Combobox(textvariable=yakit, state="readonly")
comboboxyakit['values']=sorted(list(yakit.keys()))
comboboxyakit.current(0)
comboboxyakit.grid(column=20, row=3,padx=(500, 0),pady=(10, 10))
yas={
"1980"	:"0",
"1981"	:"1",
"1982"	:"2",
"1983"	:"3",
"1984"	:"4",
"1985"	:"5",
"1986"	:"6",
"1987"	:"7",
"1988"	:"8",
"1989"	:"9",
"1990"	:"10",
"1991"	:"11",
"1992"	:"12",
"1993"	:"13",
"1994"	:"14",
"1995"	:"15",
"1996"	:"16",
"1997"	:"17",
"1998"	:"18",
"1999"	:"19",
"2000"	:"20",
"2001"	:"21",
"2002"	:"22",
"2003"	:"23",
"2004"	:"24",
"2005"	:"25",
"2006"	:"26",
"2007"	:"27",
"2008"	:"28",
"2009"	:"29",
"2010"	:"30",
"2011"	:"31",
"2012"	:"32",
"2013"	:"33",
"2014"	:"34",
"2015"	:"35",
"2016"	:"36",
"2017"	:"37",
"2018"	:"38",
"2019"	:"39",
"2020"	:"40",
"2021"	:"41",
"2022"	:"42"
}

label6 = Label( root, text = "MODEL YILI:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label6.grid(column=20, row=4,padx=(500, 250),pady=(20, 20))
comboboxyas=Combobox(textvariable=yas, state="readonly")
comboboxyas['values']=sorted(list(yas.keys()))
comboboxyas.current(len(yas)-1)
comboboxyas.grid(column=20, row=4,padx=(500, 0),pady=(10, 10))


hacim={
"1149"	:"0",
"1197"	:"1",
"1198"	:"2",
"1199"	:"3",
"1200 cm3' e kadar"	:"4",
"1201 - 1400 cm3"	:"5",
"1228"	:"6",
"1229"	:"7",
"1242"	:"8",
"1248"	:"9",
"1295"	:"10",
"1298"	:"11",
"1300"	:"12",
"1329"	:"13",
"1332"	:"14",
"1341"	:"15",
"1360"	:"16",
"1364"	:"17",
"1365"	:"18",
"1368"	:"19",
"1372"	:"20",
"1388"	:"21",
"1389"	:"22",
"1390"	:"23",
"1395"	:"24",
"1396"	:"25",
"1397"	:"26",
"1398"	:"27",
"1399"	:"28",
"1400"	:"29",
"1401 - 1600 cm3"	:"30",
"1422"	:"31",
"1461"	:"32",
"1490"	:"33",
"1493"	:"34",
"1495"	:"35",
"1497"	:"36",
"1498"	:"37",
"1499"	:"38",
"1500"	:"39",
"1560"	:"40",
"1581"	:"41",
"1582"	:"42",
"1587"	:"43",
"1590"	:"44",
"1591"	:"45",
"1592"	:"46",
"1595"	:"47",
"1596"	:"48",
"1597"	:"49",
"1598"	:"50",
"1599"	:"51",
"1600"	:"52",
"1601 - 1800 cm3"	:"53",
"1766"	:"54",
"1781"	:"55",
"1796"	:"56",
"1798"	:"57",
"1801 - 2000 cm3"	:"58",
"1834"	:"59",
"1895"	:"60",
"1896"	:"61",
"1948"	:"62",
"1951"	:"63",
"1968"	:"64",
"1988"	:"65",
"1991"	:"66",
"1995"	:"67",
"1997"	:"68",
"1998"	:"69",
"1999"	:"70",
"2001 - 2500 cm3"	:"71",
"2171"	:"72",
"5501 - 6000 cm3"	:"73",
"6001 cm3 ve üzeri"	:"74",
"898"	:"75",
"999"	:"76"

}
label7 = Label( root, text = "MOTOR HACMİ:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label7.grid(column=20, row=5,padx=(500, 260),pady=(20, 20))
comboboxhac=Combobox(textvariable=hacim, state="readonly")
comboboxhac['values']=sorted(list(hacim.keys()))
comboboxhac.current(0)
comboboxhac.grid(column=20, row=5,padx=(500, 0),pady=(10, 10))

guc={
    "100"	:"0",
"101"	:"1",
"101 - 125 HP"	:"2",
"102"	:"3",
"103"	:"4",
"105"	:"5",
"106"	:"6",
"107"	:"7",
"109"	:"8",
"110"	:"9",
"111"	:"10",
"112"	:"11",
"113"	:"12",
"114"	:"13",
"115"	:"14",
"116"	:"15",
"117"	:"16",
"118"	:"17",
"120"	:"18",
"122"	:"19",
"123"	:"20",
"124"	:"21",
"125"	:"22",
"126"	:"23",
"126 - 150 HP"	:"24",
"127"	:"25",
"128"	:"26",
"129"	:"27",
"130"	:"28",
"132"	:"29",
"136"	:"30",
"139"	:"31",
"140"	:"32",
"143"	:"33",
"145"	:"34",
"150"	:"35",
"151 - 175 HP"	:"36",
"156"	:"37",
"160"	:"38",
"163"	:"39",
"170"	:"40",
"175"	:"41",
"176 - 200 HP"	:"42",
"177"	:"43",
"180"	:"44",
"184"	:"45",
"190"	:"46",
"201 - 225 HP"	:"47",
"240"	:"48",
"326 - 350 HP"	:"49",
"476 - 500 HP"	:"50",
"50 HP'ye kadar"	:"51",
"51 - 75 HP"	:"52",
"54"	:"53",
"576 - 600 HP"	:"54",
"60"	:"55",
"601 HP ve üzeri"	:"56",
"65"	:"57",
"67"	:"58",
"68"	:"59",
"69"	:"60",
"70"	:"61",
"71"	:"62",
"72"	:"63",
"74"	:"64",
"75"	:"65",
"76"	:"66",
"76 - 100 HP"	:"67",
"77"	:"68",
"78"	:"69",
"80"	:"70",
"81"	:"71",
"82"	:"72",
"83"	:"73",
"84"	:"74",
"85"	:"75",
"86"	:"77",
"88"	:"78",
"90"	:"79",
"91"	:"80",
"92"	:"81",
"93"	:"82",
"95"	:"83",
"96"	:"84",
"97"	:"85",
"98"	:"86",
"99"	:"87"

    
}

label8 = Label( root, text = "MOTOR GÜCÜ:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label8.grid(column=20, row=6,padx=(500, 250),pady=(20, 20))
combobox_guc=Combobox(textvariable=guc, state="readonly")
combobox_guc['values']=sorted(list(guc.keys()))
combobox_guc.current(0)
combobox_guc.grid(column=20, row=6,padx=(500, 0),pady=(10, 10))


label9 = Label( root, text = "ÇEKİŞ TİPİ:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label9.grid(column=20, row=7,padx=(500, 250),pady=(20, 20))
variable_4 =StringVar()
variable_4.set("Çekiş")
cekis = {
    'Önden Çekiş':"3", 
    'Arkadan İtiş':"2", 
    '4WD (Sürekli)':"1"
}
combobox_cek = Combobox(
    master=root,
    textvariable=cekis, state="readonly"

)
combobox_cek['values']=sorted(list(cekis.keys()))
combobox_cek.current(0)
combobox_cek.grid(column=20, row=7,padx=(500, 0),pady=(10, 10))



label0= Label( root, text = "KİLOMETRE:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label0.grid(column=20, row=8,padx=(500, 225),pady=(20, 20))
kmentry=Entry()
kmentry.grid(column=20, row=8,padx=(500, 0),pady=(10, 10))

    

label11 = Label( root, text = "VİTES:",borderwidth=2, relief="solid",font=("Courier", 11, "italic"))
label11.grid(column=20, row=9,padx=(500, 210),pady=(20, 20))
variable_5 =StringVar()
variable_5.set("Vites")
vites ={
    'Düz':'0', 
    'Yarý Otomatik':"1", 
    'Otomatik':"2"}
combobox_vites = Combobox(
    master=root,
    textvariable=vites,state="readonly"
)
combobox_vites['values']=sorted(list(vites.keys()))
combobox_vites.current(0)
combobox_vites.grid(column=20, row=9,padx=(500, 0),pady=(10, 10))
"""
def encode():
    dizi=[]
    levites=vites[combobox_vites.get()]
    lecek=cekis[combobox_cek.get()]
    leguc=guc[combobox_guc.get()]
    lehacim=hacim[comboboxhac.get()]
    leyil=yas[comboboxyas.get()]
    leyak=yakit[comboboxyakit.get()]
    lekm=kmentry.get()
    dizi.append(leyil)
    dizi.append(lehacim)
    dizi.append(leguc)
    dizi.append(lecek)
    dizi.append(lekm)
    dizi.append(levites)
    dizi.append(leyak)
    return dizi"""

def modelcek():
    dizi=[]
    levites=vites[combobox_vites.get()]
    lecek=cekis[combobox_cek.get()]
    leguc=guc[combobox_guc.get()]
    lehacim=hacim[comboboxhac.get()]
    leyil=datetime.now().year-int(comboboxyas.get())
    leyak=yakit[comboboxyakit.get()]
    lekm=kmentry.get()
    dizi.append(leyil)
    dizi.append(lehacim)
    dizi.append(leguc)
    dizi.append(lecek)
    dizi.append(lekm)
    dizi.append(levites)
    dizi.append(leyak)
    get_marka=combobox_1.get()
    get_seri=combobox_2.get()
    get_model=combobox_3.get()
    """get_hacim=comboboxhac.get()
    get_beygir=combobox_guc.get()
    get_vites=combobox_vites.get()
    get_yas=comboboxyas.get()
    get_yakit=comboboxyakit.get()
    get_cekis=combobox_cek.get()"""    
    get_ozellik=combobox_1.get()+combobox_3.get()+combobox_2.get()
    get_ozellik=get_ozellik.lower()
    get_ozellik=get_ozellik.replace(" ","")
    try:
        if get_ozellik in modeldict:
            print(modeldict[get_ozellik])
            dizi.append(get_ozellik)
            print(get_ozellik)
            dizi.insert(0,modeldict[get_ozellik.replace(" ","")])
            return dizi
        else:
            messagebox.showinfo("Üzgünüz!","Girdiğiniz araç bilgilerine dair bir tahmin yürütememekteyiz en kısa zamanda yeni araçlar eklenecektir.")
    except:  
        print("Girdiğiniz araç bilgilerine dair bir tahmin yürütememekteyiz en kısa zamanda yeni araçlar eklenecektir.")

    return dizi

def predict():
    encodes=modelcek()
    print(len(encodes))
    if len(encodes)>=8:
        if (encodes[8] in modeldict):
            if str(kmentry.get())=="" or str(kmentry.get())==None :
                messagebox.showinfo("Uyarı","Boş Alan Bırakmayınız!")
            else:
                if str(kmentry.get()).isnumeric()==False:
                    messagebox.showinfo('Uyarı','Kİlometre Bilgisi Sadece Sayılardan Oluşmalıdır!')
                else:
                    loaded_model = joblib.load("aractahmin-93.sav")
                    result=loaded_model.predict(([[int(encodes[0]),int(encodes[1]),int(encodes[2]),int(encodes[3]),int(encodes[4]),int(encodes[5]),int(encodes[6]),int(encodes[7])]]))
                    result=result-(result%1000)
                    messagebox.showinfo('Fiyat', 'Aracınızın Yaklaşık Değeri --> '+str(int(result))+" Türk Lirasıdır.")
    
    
    
but= Button(root, text = "HESAPLA",command =predict)
but.grid(column=20, row=10,padx=(500, 0),pady=(10, 10))



root.mainloop()
